# %%
# ================================================
# 1️⃣ Env Prepare Install Required Packages
# ================================================

#%%capture
import os, importlib.util
# !pip install --upgrade -qqq uv
if importlib.util.find_spec("torch") is None or "COLAB_" in "".join(os.environ.keys()):    
    try: import numpy, PIL; get_numpy = f"numpy=={numpy.__version__}"; get_pil = f"pillow=={PIL.__version__}"
    except: get_numpy = "numpy"; get_pil = "pillow"
    # !uv pip install -qqq \
        "torch>=2.8.0" "triton>=3.4.0" {get_numpy} {get_pil} torchvision bitsandbytes "transformers==4.56.2" \
        "unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo" \
        "unsloth[base] @ git+https://github.com/unslothai/unsloth" \
        git+https://github.com/triton-lang/triton.git@05b2c186c1b6c9a08375389d5efe9cb4c401c075#subdirectory=python/triton_kernels
elif importlib.util.find_spec("unsloth") is None:
    # !uv pip install -qqq unsloth
# !uv pip install --upgrade --no-deps transformers==4.56.2 tokenizers trl==0.22.2 unsloth unsloth_zoo huggingface-hub==0.34.4 datasets==4.3.0 numpy==2.3.4 pandas==2.3.3 pyarrow==22.0.0 tqdm==4.67.1
# Out:
# Using Python 3.12.11 environment at: /home/zeus/miniconda3/envs/cloudspace
# Resolved 11 packages in 34ms
# Audited 11 packages in 0.60ms

# %%
import torch
import bitsandbytes as bnb
from collections import Counter
from unsloth import FastLanguageModel


model, tokenizer = FastLanguageModel.from_pretrained(
    "unsloth/gpt-oss-20b",
    load_in_4bit=True,
)

bnb_layers = []
for name, module in model.named_modules():
    if isinstance(module, bnb.nn.Linear4bit):
        bnb_layers.append(name)

print(f"BNB 4-bit layers found: {len(bnb_layers)}")
print("Sample BNB layer:", bnb_layers[0] if bnb_layers else "❌ NONE")
print("Model compute dtype:", model.dtype)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.12.10: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    NVIDIA L40S. Num GPUs = 1. Max memory: 44.521 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# BNB 4-bit layers found: 1632
# Sample BNB layer: model.layers.0.self_attn.q_proj
# Model compute dtype: torch.bfloat16

# %%
model = FastLanguageModel.get_peft_model(
    model,
    checkpoint_path="ospost/gpt-oss-20b-sft-adapter"
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %%
assert any("lora_" in n for n,_ in model.named_parameters())

lora_params = [
    (n, p) for n, p in model.named_parameters() if "lora_" in n
]

print(f"LoRA parameters found: {len(lora_params)}")
print("Sample LoRA param:", lora_params[0][0] if lora_params else "❌ NONE")

print("LoRA dtypes:", Counter(p.dtype for _, p in lora_params))

trainable = [
    n for n, p in model.named_parameters() if p.requires_grad
]

print(f"Trainable params count: {len(trainable)}")
print("Sample trainable param:", trainable[0] if trainable else "❌ NONE")
# Out:
# LoRA parameters found: 192
# Sample LoRA param: base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight
# LoRA dtypes: Counter({torch.float32: 192})
# Trainable params count: 192
# Sample trainable param: base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight

# %%
model.save_pretrained_merged(
    "gpt-oss-20b-sft-4bit",
    tokenizer,
    save_method="merged_4bit",
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.save_pretrained_merged(
#       2     "gpt-oss-20b-sft-4bit",
#       3     tokenizer,
#       4     save_method="merged_4bit",
#       5 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/unsloth/save.py:2694, in unsloth_generic_save_pretrained_merged(self, save_directory, tokenizer, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, tags, temporary_location, maximum_memory_usage)
#    2692 arguments["model"] = self
#    2693 del arguments["self"]
# -> 2694 unsloth_generic_save(**arguments)
#    2695 for _ in range(3):
#    2696     gc.collect()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/unsloth/save.py:2633, in unsloth_generic_save(model, tokenizer, save_directory, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, use_temp_dir, commit_message, private, create_pr, revision, commit_description, tags, temporary_location, maximum_memory_usage)
#    2630     token = get_token()
#    2632 if save_method == "merged_4bit":
# -> 2633     raise RuntimeError(
#    2634         "Unsloth: Merging into 4bit will cause your model to lose accuracy if you plan\n"
#    2635         "to merge to GGUF or others later on. I suggest you to do this as a final step\n"
#    2636         "if you're planning to do multiple saves.\n"
#    2637         "If you are certain, change `save_method` to `merged_4bit_forced`."
#    2638     )
#    2639 elif save_method == "merged_4bit_forced":
#    2640     save_method = "merged_4bit"
#
# RuntimeError: Unsloth: Merging into 4bit will cause your model to lose accuracy if you plan
# to merge to GGUF or others later on. I suggest you to do this as a final step
# if you're planning to do multiple saves.
# If you are certain, change `save_method` to `merged_4bit_forced`.

# %%
model, _ = FastLanguageModel.from_pretrained(
    "gpt-oss-20b-sft-4bit",
    load_in_4bit=False,
)

assert not any("lora_" in n for n,_ in model.named_parameters())

has_lora = any("lora_" in n for n, _ in merged_model.named_parameters())
print("LoRA present after merge:", has_lora)

trainable_after_merge = [
    n for n, p in merged_model.named_parameters() if p.requires_grad
]

print("Trainable params after merge:", len(trainable_after_merge))

bnb_after = [
    n for n, m in merged_model.named_modules()
    if isinstance(m, bnb.nn.Linear4bit)
]

print("BNB layers after merge:", len(bnb_after))
# Out:
# ==((====))==  Unsloth 2025.12.10: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    NVIDIA H200. Num GPUs = 1. Max memory: 139.811 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 9.0. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model, _ = FastLanguageModel.from_pretrained(
#       2     "gpt-oss-20b-sft-mxfp4",
#       3     load_in_4bit=False,
#       4 )
#       6 assert not any("lora_" in n for n,_ in model.named_parameters())
#       8 has_lora = any("lora_" in n for n, _ in merged_model.named_parameters())
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/unsloth/models/loader.py:494, in FastLanguageModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, load_in_16bit, full_finetuning, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, revision, use_exact_model_name, offload_embedding, float32_mixed_precision, fast_inference, gpu_memory_utilization, float8_kv_cache, random_state, max_lora_rank, disable_log_stats, qat_scheme, load_in_fp8, unsloth_tiled_mlp, *args, **kwargs)
#     475     dispatch_model = (
#     476         FastQwen3Model if model_type == "qwen3" else FastQwen3MoeModel
#     477     )
#     478 # elif model_type == "falcon_h1":
#     479 #     dispatch_model = FastFalconH1Model
#     480 #     if not SUPPORTS_FALCON_H1:
#    (...)
#     492 #     dispatch_model = FastGraniteModel
#     493 else:
# --> 494     return FastModel.from_pretrained(
#     495         model_name = old_model_name,
#     496         max_seq_length = max_seq_length,
#     497         dtype = dtype,
#     498         load_in_4bit = load_in_4bit,
#     499         load_in_8bit = load_in_8bit,
#     500         load_in_16bit = load_in_16bit,
#     501         full_finetuning = full_finetuning,
#     502         token = token,
#     503         device_map = device_map,
#     504         rope_scaling = rope_scaling,  # [TODO] No effect
#     505         fix_tokenizer = fix_tokenizer,  # [TODO] No effect
#     506         trust_remote_code = trust_remote_code,
#     507         use_gradient_checkpointing = use_gradient_checkpointing,
#     508         resize_model_vocab = resize_model_vocab,  # [TODO] No effect
#     509         revision = revision,
#     510         return_logits = False,  # Return logits
#     511         fullgraph = True,  # No graph breaks
#     512         use_exact_model_name = use_exact_model_name,
#     513         offload_embedding = offload_embedding,
#     514         float32_mixed_precision = float32_mixed_precision,
#     515         # Pass vLLM/inference parameters
#     516         fast_inference = fast_inference,
#     517         gpu_memory_utilization = gpu_memory_utilization,
#     518         float8_kv_cache = float8_kv_cache,
#     519         random_state = random_state,
#     520         max_lora_rank = max_lora_rank,
#     521         disable_log_stats = disable_log_stats,
#     522         qat_scheme = qat_scheme,
#     523         load_in_fp8 = load_in_fp8,
#     524         unsloth_tiled_mlp = unsloth_tiled_mlp,
#     525         *args,
#     526         **kwargs,
#     527     )
#     529 if use_gradient_checkpointing == "unsloth":
#     530     patch_unsloth_smart_gradient_checkpointing(dtype = dtype)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/unsloth/models/loader.py:1172, in FastModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, load_in_16bit, full_finetuning, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, revision, return_logits, fullgraph, use_exact_model_name, auto_model, whisper_language, whisper_task, unsloth_force_compile, offload_embedding, float32_mixed_precision, fast_inference, gpu_memory_utilization, float8_kv_cache, random_state, max_lora_rank, disable_log_stats, qat_scheme, load_in_fp8, unsloth_tiled_mlp, *args, **kwargs)
#    1169 if auto_model is None:
#    1170     auto_model = AutoModelForVision2Seq if is_vlm else AutoModelForCausalLM
# -> 1172 model, tokenizer = FastBaseModel.from_pretrained(
#    1173     model_name = model_name,
#    1174     max_seq_length = max_seq_length,
#    1175     dtype = _get_dtype(dtype),
#    1176     load_in_4bit = load_in_4bit,
#    1177     load_in_8bit = load_in_8bit,
#    1178     load_in_16bit = load_in_16bit,
#    1179     full_finetuning = full_finetuning,
#    1180     token = token,
#    1181     device_map = device_map,
#    1182     trust_remote_code = trust_remote_code,
#    1183     revision = revision if not is_peft else None,
#    1184     model_types = model_types,
#    1185     tokenizer_name = tokenizer_name,
#    1186     auto_model = auto_model,
#    1187     use_gradient_checkpointing = use_gradient_checkpointing,
#    1188     supports_sdpa = supports_sdpa,
#    1189     whisper_language = whisper_language,
#    1190     whisper_task = whisper_task,
#    1191     auto_config = model_config,
#    1192     offload_embedding = offload_embedding,
#    1193     float32_mixed_precision = float32_mixed_precision,
#    1194     # Pass vLLM/inference parameters
#    1195     fast_inference = fast_inference,
#    1196     gpu_memory_utilization = gpu_memory_utilization,
#    1197     float8_kv_cache = float8_kv_cache,
#    1198     random_state = random_state,
#    1199     max_lora_rank = max_lora_rank,
#    1200     disable_log_stats = disable_log_stats,
#    1201     *args,
#    1202     **kwargs,
#    1203 )
#    1205 if resize_model_vocab is not None:
#    1206     model.resize_token_embeddings(resize_model_vocab)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/unsloth/models/vision.py:665, in FastBaseModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, load_in_8bit, load_in_16bit, full_finetuning, token, device_map, trust_remote_code, model_types, tokenizer_name, auto_model, use_gradient_checkpointing, supports_sdpa, whisper_language, whisper_task, auto_config, offload_embedding, float32_mixed_precision, fast_inference, gpu_memory_utilization, float8_kv_cache, random_state, max_lora_rank, disable_log_stats, unsloth_vllm_standby, **kwargs)
#     662 if not fast_inference:
#     663     # Prevent load_in_fp8 from being forwarded into HF internal model loading
#     664     load_in_fp8 = kwargs.pop("load_in_fp8", None)
# --> 665     model = auto_model.from_pretrained(
#     666         model_name,
#     667         device_map = device_map,
#     668         # torch_dtype           = torch_dtype, # Transformers removed torch_dtype
#     669         # quantization_config   = bnb_config,
#     670         token = token,
#     671         trust_remote_code = trust_remote_code,
#     672         # attn_implementation   = attn_implementation,
#     673         **kwargs,
#     674     )
#     675     if hasattr(model, "generate"):
#     676         model.fast_generate = make_fast_generate_wrapper(model.generate)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:5179, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    5169     if dtype_orig is not None:
#    5170         torch.set_default_dtype(dtype_orig)
#    5172     (
#    5173         model,
#    5174         missing_keys,
#    5175         unexpected_keys,
#    5176         mismatched_keys,
#    5177         offload_index,
#    5178         error_msgs,
# -> 5179     ) = cls._load_pretrained_model(
#    5180         model,
#    5181         state_dict,
#    5182         checkpoint_files,
#    5183         pretrained_model_name_or_path,
#    5184         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    5185         sharded_metadata=sharded_metadata,
#    5186         device_map=device_map,
#    5187         disk_offload_folder=offload_folder,
#    5188         offload_state_dict=offload_state_dict,
#    5189         dtype=dtype,
#    5190         hf_quantizer=hf_quantizer,
#    5191         keep_in_fp32_regex=keep_in_fp32_regex,
#    5192         device_mesh=device_mesh,
#    5193         key_mapping=key_mapping,
#    5194         weights_only=weights_only,
#    5195     )
#    5196 # make sure token embedding weights are still tied if needed
#    5197 model.tie_weights()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:5496, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5493 model._move_missing_keys_from_meta_to_cpu(missing_keys + mismatched_keys, unexpected_keys, dtype, hf_quantizer)
#    5495 # correctly initialize the missing (and potentially mismatched) keys
# -> 5496 model._initialize_missing_keys(checkpoint_keys, ignore_mismatched_sizes, is_quantized)
#    5498 # Set some modules to fp32 if needed
#    5499 if keep_in_fp32_regex is not None:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:6068, in PreTrainedModel._initialize_missing_keys(self, loaded_keys, ignore_mismatched_sizes, is_quantized)
#    6066         self.initialize_weights()
#    6067 else:
# -> 6068     self.initialize_weights()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3105, in PreTrainedModel.initialize_weights(self)
#    3102     torch.nn.Module.smart_apply = smart_apply
#    3104 # Let the magic happen with this simple call
# -> 3105 self.smart_apply(self._initialize_weights)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3096, in PreTrainedModel.initialize_weights.<locals>.smart_apply(self, fn)
#    3093 for module in self.children():
#    3094     # We found a sub-model: recursively dispatch its own init function now!
#    3095     if isinstance(module, PreTrainedModel):
# -> 3096         module.smart_apply(module._initialize_weights)
#    3097     else:
#    3098         module.smart_apply(fn)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3098, in PreTrainedModel.initialize_weights.<locals>.smart_apply(self, fn)
#    3096         module.smart_apply(module._initialize_weights)
#    3097     else:
# -> 3098         module.smart_apply(fn)
#    3099 fn(self)
#    3100 return self
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3098, in PreTrainedModel.initialize_weights.<locals>.smart_apply(self, fn)
#    3096         module.smart_apply(module._initialize_weights)
#    3097     else:
# -> 3098         module.smart_apply(fn)
#    3099 fn(self)
#    3100 return self
#
#     [... skipping similar frames: PreTrainedModel.initialize_weights.<locals>.smart_apply at line 3098 (1 times)]
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3098, in PreTrainedModel.initialize_weights.<locals>.smart_apply(self, fn)
#    3096         module.smart_apply(module._initialize_weights)
#    3097     else:
# -> 3098         module.smart_apply(fn)
#    3099 fn(self)
#    3100 return self
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3099, in PreTrainedModel.initialize_weights.<locals>.smart_apply(self, fn)
#    3097     else:
#    3098         module.smart_apply(fn)
# -> 3099 fn(self)
#    3100 return self
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/modeling_utils.py:3073, in PreTrainedModel._initialize_weights(self, module)
#    3071 if getattr(module, "_is_hf_initialized", False):
#    3072     return
# -> 3073 self._init_weights(module)
#    3074 module._is_hf_initialized = True
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/transformers/models/gpt_oss/modeling_gpt_oss.py:430, in GptOssPreTrainedModel._init_weights(self, module)
#     428     module.sinks.data.normal_(mean=0.0, std=std)
#     429 elif isinstance(module, GptOssTopKRouter):
# --> 430     module.weight.data.normal_(mean=0.0, std=std)
#     431     module.bias.data.normal_(mean=0.0, std=std)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torch/nn/modules/module.py:1962, in Module.__getattr__(self, name)
#    1960     if name in modules:
#    1961         return modules[name]
# -> 1962 raise AttributeError(
#    1963     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1964 )
#
# AttributeError: 'GptOssTopKRouter' object has no attribute 'weight'

# %%
# model.push_to_hub("ospost/gpt-oss-20b-sft-mxfp4", token = "")

# %%
# git clone https://github.com/ggerganov/llama.cpp
# cd llama.cpp

# python convert_hf_to_gguf.py \
#  gpt-oss-20b-sft-mxfp4 \
#  --outtype q4_K_M \
#  --outfile gpt-oss-20b-sft-q4_K_M.gguf
